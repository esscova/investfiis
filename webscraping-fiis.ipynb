# %% [markdown]
# # WebScraping

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
URL = 'https://fiis.com.br/lista-de-fundos-imobiliarios/'

HEADER = {
    "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# %%
page = requests.get(URL, headers=HEADER)
site = bs(page.content,'html.parser')

# %%
divs = site.find_all('div',{"class":"tickerBox"})

fiis = [
    {
        "ticker": div.find('div', {"class": "tickerBox__title"}).text,
        "dy": div.find_all('div', {"class": "tickerBox__info__box"})[0].text
    }
    for div in divs
]

# %%
fiis
# Out:
# [{'ticker': 'AAGR11', 'dy': '-'},
#  {'ticker': 'AAZQ11', 'dy': '16,87'},
#  {'ticker': 'ABCP11', 'dy': '8,79'},
#  {'ticker': 'AFCR11', 'dy': '-'},
#  {'ticker': 'AFHI11', 'dy': '12,75'},
#  {'ticker': 'AFOF11', 'dy': '-'},
#  {'ticker': 'AGRX11', 'dy': '18,60'},
#  {'ticker': 'AIEC11', 'dy': '16,55'},
#  {'ticker': 'AJFI11', 'dy': '-'},
#  {'ticker': 'ALMI11', 'dy': '-'},
#  {'ticker': 'ALZC11', 'dy': '-'},
#  {'ticker': 'ALZM11', 'dy': '117,61'},
#  {'ticker': 'ALZR11', 'dy': '8,19'},
#  {'ticker': 'AMAZ11', 'dy': '-'},
#  {'ticker': 'ANCR11B', 'dy': '1,96'},
#  {'ticker': 'APTO11', 'dy': '12,39'},
#  {'ticker': 'APXM11', 'dy': '1,97'},
#  {'ticker': 'AQLL11', 'dy': '-'},
#  {'ticker': 'ARCT11', 'dy': '16,59'},
#  {'ticker': 'ARFI11B', 'dy': '-'},
#  {'ticker': 'AROA11', 'dy': '3,15'},
#  {'ticker': 'ARRI11', 'dy': '13,73'},
#  {'ticker': 'ARXD11', 'dy': '10,36'},
#  {'ticker': 'ASMT11', 'dy': '2,80'},
#  {'ticker': 'ASRF11', 'dy': '2,54'},
#  {'ticker': 'ATCR11', 'dy': '-'},
#  {'ticker': 'ATSA11', 'dy': '0,18'},
#  {'ticker': 'ATSA11B', 'dy': '-'},
#  {'ticker': 'ATWN11', 'dy': '-'},
#  {'ticker': 'AURB11', 'dy': '6,16'},
#  {'ticker': 'BARI11', 'dy': '11,01'},
#  {'ticker': 'BBFI11B', 'dy': '13,55'},
#  {'ticker': 'BBFO11', 'dy': '11,05'},
#  {'ticker': 'BBGO11', 'dy': '13,40'},
#  {'ticker': 'BBIM11', 'dy': '-'},
#  {'ticker': 'BBPO11', 'dy': '10,89'},
#  {'ticker': 'BBRC11', 'dy': '11,37'},
#  {'ticker': 'BBVJ11', 'dy': '-'},
#  {'ticker': 'BCFF11', 'dy': '9,23'},
#  {'ticker': 'BCIA11', 'dy': '9,22'},
#  {'ticker': 'BCRI11', 'dy': '12,40'},
#  {'ticker': 'BETW11', 'dy': '-'},
#  {'ticker': 'BICE11', 'dy': '12,66'},
#  {'ticker': 'BICR11', 'dy': '11,63'},
#  {'ticker': 'BIME11', 'dy': '13,47'},
#  {'ticker': 'BIPD11', 'dy': '-'},
#  {'ticker': 'BIPE11', 'dy': '-'},
#  {'ticker': 'BLCA11', 'dy': '14,84'},
#  {'ticker': 'BLCP11', 'dy': '0,62'},
#  {'ticker': 'BLMC11', 'dy': '11,22'},
#  {'ticker': 'BLMG11', 'dy': '18,84'},
#  {'ticker': 'BLMO11', 'dy': '1.020,45'},
#  {'ticker': 'BLMR11', 'dy': '8,97'},
#  {'ticker': 'BLUR11', 'dy': '11,89'},
#  {'ticker': 'BMII11', 'dy': '-'},
#  {'ticker': 'BMLC11', 'dy': '11,12'},
#  {'ticker': 'BMLC11B', 'dy': '-'},
#  {'ticker': 'BNFS11', 'dy': '14,22'},
#  {'ticker': 'BPFF11', 'dy': '9,91'},
#  {'ticker': 'BPLC11', 'dy': '-'},
#  {'ticker': 'BPML11', 'dy': '0,57'},
#  {'ticker': 'BPRP11', 'dy': '9,97'},
#  {'ticker': 'BRCO11', 'dy': '8,21'},
#  {'ticker': 'BRCR11', 'dy': '8,68'},
#  {'ticker': 'BREV11', 'dy': '4,99'},
#  {'ticker': 'BRHT11B', 'dy': '-'},
#  {'ticker': 'BRIM11', 'dy': '23,88'},
#  {'ticker': 'BRIP11', 'dy': '17,89'},
#  {'ticker': 'BRIX11', 'dy': '-'},
#  {'ticker': 'BRLA11', 'dy': '9,33'},
#  {'ticker': 'BROF11', 'dy': '8,26'},
#  {'ticker': 'BRSE11', 'dy': '-'},
#  {'ticker': 'BTAG11', 'dy': '-'},
#  {'ticker': 'BTAL11', 'dy': '11,47'},
#  {'ticker': 'BTCI11', 'dy': '12,28'},
#  {'ticker': 'BTCR11', 'dy': '1,02'},
#  {'ticker': 'BTHI11', 'dy': '22,96'},
#  {'ticker': 'BTLG11', 'dy': '8,70'},
#  {'ticker': 'BTRA11', 'dy': '13,90'},
#  {'ticker': 'BTSG11', 'dy': '7,71'},
#  {'ticker': 'BTSI11', 'dy': '8,88'},
#  {'ticker': 'BTWR11', 'dy': '6,08'},
#  {'ticker': 'BVAR11', 'dy': '-'},
#  {'ticker': 'BZEL11', 'dy': '-'},
#  {'ticker': 'BZLI11', 'dy': '-'},
#  {'ticker': 'CACR11', 'dy': '17,09'},
#  {'ticker': 'CARE11', 'dy': '-'},
#  {'ticker': 'CBOP11', 'dy': '4,65'},
#  {'ticker': 'CCLB11', 'dy': '-'},
#  {'ticker': 'CCME11', 'dy': '10,04'},
#  {'ticker': 'CCRF11', 'dy': '8,70'},
#  {'ticker': 'CEOC11', 'dy': '14,50'},
#  {'ticker': 'CFHI11', 'dy': '0,60'},
#  {'ticker': 'CFII11', 'dy': '-'},
#  {'ticker': 'CIXR11', 'dy': '-'},
#  {'ticker': 'CJCT11', 'dy': '1,90'},
#  {'ticker': 'CJFI11', 'dy': '-'},
#  {'ticker': 'CLIN11', 'dy': '-'},
#  {'ticker': 'CNES11', 'dy': '4,86'},
#  {'ticker': 'COPP11', 'dy': '0,73'},
#  {'ticker': 'CORM11', 'dy': '-'},
#  {'ticker': 'CPFF11', 'dy': '8,90'},
#  {'ticker': 'CPFO11', 'dy': '-'},
#  {'ticker': 'CPSH11', 'dy': '5,44'},
#  {'ticker': 'CPTR11', 'dy': '16,31'},
#  {'ticker': 'CPTS11', 'dy': '10,21'},
#  {'ticker': 'CRAA11', 'dy': '13,66'},
#  {'ticker': 'CRFF11', 'dy': '9,38'},
#  {'ticker': 'CSMC11', 'dy': '-'},
#  {'ticker': 'CTNP11', 'dy': '-'},
#  {'ticker': 'CTXT11', 'dy': '-'},
#  {'ticker': 'CVBI11', 'dy': '12,03'},
#  {'ticker': 'CVPR11', 'dy': '-'},
#  {'ticker': 'CXAG11', 'dy': '10,76'},
#  {'ticker': 'CXCE11B', 'dy': '10,94'},
#  {'ticker': 'CXCI11', 'dy': '11,73'},
#  {'ticker': 'CXCO11', 'dy': '11,72'},
#  {'ticker': 'CXRI11', 'dy': '8,60'},
#  {'ticker': 'CXTL11', 'dy': '8,58'},
#  {'ticker': 'CYCR11', 'dy': '12,96'},
#  {'ticker': 'CYLD11', 'dy': '-'},
#  {'ticker': 'DAMT11B', 'dy': '7,93'},
#  {'ticker': 'DCRA11', 'dy': '15,78'},
#  {'ticker': 'DEVA11', 'dy': '18,40'},
#  {'ticker': 'DLMT11', 'dy': '-'},
#  {'ticker': 'DMAC11', 'dy': '37,65'},
#  {'ticker': 'DOMC11', 'dy': '-'},
#  {'ticker': 'DOVL11B', 'dy': '8,49'},
#  {'ticker': 'DPRO11', 'dy': '95,17'},
#  {'ticker': 'DRIT11B', 'dy': '9,51'},
#  {'ticker': 'DVFF11', 'dy': '10,91'},
#  {'ticker': 'EDFO11B', 'dy': '9,03'},
#  {'ticker': 'EDGA11', 'dy': '5,41'},
#  {'ticker': 'EGAF11', 'dy': '16,52'},
#  {'ticker': 'EGYR11', 'dy': '-'},
#  {'ticker': 'ELDO11B', 'dy': '13,69'},
#  {'ticker': 'EQIN11', 'dy': '-'},
#  {'ticker': 'EQIR11', 'dy': '13,54'},
#  {'ticker': 'ERCR11', 'dy': '0,18'},
#  {'ticker': 'ERPA11', 'dy': '7,13'},
#  {'ticker': 'ESTQ11', 'dy': '-'},
#  {'ticker': 'EURO11', 'dy': '8,98'},
#  {'ticker': 'EVBI11', 'dy': '9,32'},
#  {'ticker': 'EXES11', 'dy': '11,05'},
#  {'ticker': 'FAED11', 'dy': '11,87'},
#  {'ticker': 'FAGL11', 'dy': '-'},
#  {'ticker': 'FAMB11B', 'dy': '-'},
#  {'ticker': 'FAOE11', 'dy': '-'},
#  {'ticker': 'FARU11', 'dy': '-'},
#  {'ticker': 'FATN11', 'dy': '10,88'},
#  {'ticker': 'FCFL11', 'dy': '8,24'},
#  {'ticker': 'FEXC11', 'dy': '25,95'},
#  {'ticker': 'FGAA11', 'dy': '16,47'},
#  {'ticker': 'FGPM11', 'dy': '-'},
#  {'ticker': 'FIGS11', 'dy': '8,89'},
#  {'ticker': 'FIIB11', 'dy': '8,05'},
#  {'ticker': 'FIIP11B', 'dy': '9,40'},
#  {'ticker': 'FINF11', 'dy': '-'},
#  {'ticker': 'FISC11', 'dy': '7,45'},
#  {'ticker': 'FISD11', 'dy': '-'},
#  {'ticker': 'FIVN11', 'dy': '-'},
#  {'ticker': 'FIXX11', 'dy': '-'},
#  {'ticker': 'FLCR11', 'dy': '13,81'},
#  {'ticker': 'FLEM11', 'dy': '-'},
#  {'ticker': 'FLFL11', 'dy': '-'},
#  {'ticker': 'FLMA11', 'dy': '7,96'},
#  {'ticker': 'FLRP11', 'dy': '8,47'},
#  {'ticker': 'FMOF11', 'dy': '1,07'},
#  {'ticker': 'FPAB11', 'dy': '9,56'},
#  {'ticker': 'FPNG11', 'dy': '8,26'},
#  {'ticker': 'FRHY11', 'dy': '-'},
#  {'ticker': 'FTCE11B', 'dy': '6,86'},
#  {'ticker': 'FVBI11', 'dy': '-'},
#  {'ticker': 'FVPQ11', 'dy': '11,02'},
#  {'ticker': 'FZDA11', 'dy': '1,85'},
#  {'ticker': 'FZDB11', 'dy': '-'},
#  {'ticker': 'GALG11', 'dy': '10,79'},
#  {'ticker': 'GAME11', 'dy': '12,86'},
#  {'ticker': 'GCFF11', 'dy': '4,21'},
#  {'ticker': 'GCOI11', 'dy': '0,81'},
#  {'ticker': 'GCRA11', 'dy': '18,28'},
#  {'ticker': 'GCRI11', 'dy': '13,93'},
#  {'ticker': 'GESE11B', 'dy': '87,27'},
#  {'ticker': 'GGRC11', 'dy': '10,22'},
#  {'ticker': 'GLOG11', 'dy': '12,05'},
#  {'ticker': 'GRLV11', 'dy': '-'},
#  {'ticker': 'GRWA11', 'dy': '11,27'},
#  {'ticker': 'GSFI11', 'dy': '-'},
#  {'ticker': 'GTLG11', 'dy': '6,78'},
#  {'ticker': 'GTWR11', 'dy': '10,76'},
#  {'ticker': 'GURB11', 'dy': '5,32'},
#  {'ticker': 'GVBI11', 'dy': '-'},
#  {'ticker': 'GZIT11', 'dy': '-'},
#  {'ticker': 'HAAA11', 'dy': '9,54'},
#  {'ticker': 'HABT11', 'dy': '15,29'},
#  {'ticker': 'HBCR11', 'dy': '6,14'},
#  {'ticker': 'HBRH11', 'dy': '7,26'},
#  {'ticker': 'HBTT11', 'dy': '-'},
#  {'ticker': 'HCHG11', 'dy': '13,20'},
#  {'ticker': 'HCPR11', 'dy': '-'},
#  {'ticker': 'HCRA11', 'dy': '-'},
#  {'ticker': 'HCRI11', 'dy': '11,01'},
#  {'ticker': 'HCST11', 'dy': '-'},
#  {'ticker': 'HCTR11', 'dy': '14,97'},
#  {'ticker': 'HDEL11', 'dy': '12,53'},
#  {'ticker': 'HDOF11', 'dy': '-'},
#  {'ticker': 'HFOF11', 'dy': '9,67'},
#  {'ticker': 'HGAG11', 'dy': '14,67'},
#  {'ticker': 'HGBS11', 'dy': '8,82'},
#  {'ticker': 'HGCR11', 'dy': '12,82'},
#  {'ticker': 'HGFF11', 'dy': '9,10'},
#  {'ticker': 'HGIC11', 'dy': '11,31'},
#  {'ticker': 'HGLG11', 'dy': '8,39'},
#  {'ticker': 'HGPO11', 'dy': '6,64'},
#  {'ticker': 'HGRE11', 'dy': '7,78'},
#  {'ticker': 'HGRS11', 'dy': '-'},
#  {'ticker': 'HGRU11', 'dy': '8,76'},
#  {'ticker': 'HILG11', 'dy': '-'},
#  {'ticker': 'HLOG11', 'dy': '9,28'},
#  {'ticker': 'HMOC11', 'dy': '-'},
#  {'ticker': 'HOFC11', 'dy': '12,36'},
#  {'ticker': 'HOSI11', 'dy': '8,58'},
#  {'ticker': 'HPDP11', 'dy': '7,36'},
#  {'ticker': 'HRDF11', 'dy': '-'},
#  {'ticker': 'HREC11', 'dy': '112,67'},
#  {'ticker': 'HRES11', 'dy': '-'},
#  {'ticker': 'HSAF11', 'dy': '12,57'},
#  {'ticker': 'HSLG11', 'dy': '9,01'},
#  {'ticker': 'HSML11', 'dy': '9,33'},
#  {'ticker': 'HSRE11', 'dy': '7,19'},
#  {'ticker': 'HTMX11', 'dy': '14,00'},
#  {'ticker': 'HUCG11', 'dy': '3,37'},
#  {'ticker': 'HUSC11', 'dy': '8,91'},
#  {'ticker': 'HUSI11', 'dy': '8,89'},
#  {'ticker': 'IAAG11', 'dy': '5,31'},
#  {'ticker': 'IAGR11', 'dy': '-'},
#  {'ticker': 'IBCR11', 'dy': '13,63'},
#  {'ticker': 'IBFF11', 'dy': '0,45'},
#  {'ticker': 'ICRI11', 'dy': '-'},
#  {'ticker': 'IDFI11', 'dy': '20,70'},
#  {'ticker': 'IDGR11', 'dy': '3,78'},
#  {'ticker': 'IFID11', 'dy': '-'},
#  {'ticker': 'IFIE11', 'dy': '-'},
#  {'ticker': 'IRDM11', 'dy': '12,28'},
#  {'ticker': 'IRIM11', 'dy': '13,24'},
#  {'ticker': 'ITIP11', 'dy': '12,13'},
#  {'ticker': 'ITIT11', 'dy': '9,12'},
#  {'ticker': 'JASC11', 'dy': '5,31'},
#  {'ticker': 'JBFO11', 'dy': '6,13'},
#  {'ticker': 'JCCJ11', 'dy': '0,78'},
#  {'ticker': 'JCDA11', 'dy': '-'},
#  {'ticker': 'JCDB11', 'dy': '-'},
#  {'ticker': 'JFLL11', 'dy': '9,89'},
#  {'ticker': 'JGPX11', 'dy': '15,08'},
#  {'ticker': 'JPPA11', 'dy': '15,66'},
#  {'ticker': 'JPPC11', 'dy': '0,09'},
#  {'ticker': 'JRDM11', 'dy': '4,40'},
#  {'ticker': 'JSAF11', 'dy': '11,27'},
#  {'ticker': 'JSRE11', 'dy': '7,23'},
#  {'ticker': 'JTPR11', 'dy': '-'},
#  {'ticker': 'KCRE11', 'dy': '11,76'},
#  {'ticker': 'KEVE11', 'dy': '0,46'},
#  {'ticker': 'KFOF11', 'dy': '9,31'},
#  {'ticker': 'KINP11', 'dy': '65,42'},
#  {'ticker': 'KISU11', 'dy': '10,70'},
#  {'ticker': 'KIVO11', 'dy': '17,23'},
#  {'ticker': 'KLOG11', 'dy': '-'},
#  {'ticker': 'KNCA11', 'dy': '13,45'},
#  {'ticker': 'KNCR11', 'dy': '12,97'},
#  {'ticker': 'KNHF11', 'dy': '4,74'},
#  {'ticker': 'KNHY11', 'dy': '12,33'},
#  {'ticker': 'KNIP11', 'dy': '9,98'},
#  {'ticker': 'KNPR11', 'dy': '-'},
#  {'ticker': 'KNRE11', 'dy': '9,21'},
#  {'ticker': 'KNRI11', 'dy': '7,40'},
#  {'ticker': 'KNSC11', 'dy': '11,10'},
#  {'ticker': 'KNUQ11', 'dy': '6,25'},
#  {'ticker': 'KOPA11', 'dy': '-'},
#  {'ticker': 'LASC11', 'dy': '7,28'},
#  {'ticker': 'LATR11B', 'dy': '202,33'},
#  {'ticker': 'LAVF11', 'dy': '-'},
#  {'ticker': 'LFTT11', 'dy': '6,40'},
#  {'ticker': 'LGCP11', 'dy': '8,62'},
#  {'ticker': 'LIFE11', 'dy': '15,65'},
#  {'ticker': 'LKDV11', 'dy': '-'},
#  {'ticker': 'LLAO11', 'dy': '3,12'},
#  {'ticker': 'LOFT11B', 'dy': '-'},
#  {'ticker': 'LPLP11', 'dy': '-'},
#  {'ticker': 'LRDI11', 'dy': '-'},
#  {'ticker': 'LSAG11', 'dy': '17,08'},
#  {'ticker': 'LSPA11', 'dy': '12,84'},
#  {'ticker': 'LTMT11', 'dy': '-'},
#  {'ticker': 'LUGG11', 'dy': '8,24'},
#  {'ticker': 'LVBI11', 'dy': '8,05'},
#  {'ticker': 'MALL11', 'dy': '8,16'},
#  {'ticker': 'MANA11', 'dy': '13,97'},
#  {'ticker': 'MATV11', 'dy': '3,00'},
#  {'ticker': 'MAVC11', 'dy': '-'},
#  {'ticker': 'MAXR11', 'dy': '10,90'},
#  {'ticker': 'MBRF11', 'dy': '-'},
#  {'ticker': 'MCCI11', 'dy': '12,01'},
#  {'ticker': 'MCHF11', 'dy': '12,27'},
#  {'ticker': 'MCHY11', 'dy': '137,09'},
#  {'ticker': 'MFAI11', 'dy': '9,40'},
#  {'ticker': 'MFCR11', 'dy': '14,39'},
#  {'ticker': 'MFII11', 'dy': '13,48'},
#  {'ticker': 'MGCR11', 'dy': '8,39'},
#  {'ticker': 'MGFF11', 'dy': '8,22'},
#  {'ticker': 'MGHT11', 'dy': '17,12'},
#  {'ticker': 'MGIM11', 'dy': '0,17'},
#  {'ticker': 'MGLC11', 'dy': '-'},
#  {'ticker': 'MGLG11', 'dy': '10,23'},
#  {'ticker': 'MGRI11', 'dy': '-'},
#  {'ticker': 'MINT11', 'dy': '1,32'},
#  {'ticker': 'MMPD11', 'dy': '-'},
#  {'ticker': 'MMVE11', 'dy': '-'},
#  {'ticker': 'MOFF11', 'dy': '-'},
#  {'ticker': 'MORC11', 'dy': '14,69'},
#  {'ticker': 'MORE11', 'dy': '8,84'},
#  {'ticker': 'MTOF11', 'dy': '-'},
#  {'ticker': 'MTRS11', 'dy': '-'},
#  {'ticker': 'MVFI11', 'dy': '-'},
#  {'ticker': 'MXRF11', 'dy': '12,98'},
#  {'ticker': 'MYDW11', 'dy': '-'},
#  {'ticker': 'NAVT11', 'dy': '12,73'},
#  {'ticker': 'NCHB11', 'dy': '13,80'},
#  {'ticker': 'NCRA11', 'dy': '16,94'},
#  {'ticker': 'NCRI11', 'dy': '11,46'},
#  {'ticker': 'NEWL11', 'dy': '10,16'},
#  {'ticker': 'NEWU11', 'dy': '2,99'},
#  {'ticker': 'NEXG11', 'dy': '-'},
#  {'ticker': 'NPAR11', 'dy': '-'},
#  {'ticker': 'NSLU11', 'dy': '9,52'},
#  {'ticker': 'NVHO11', 'dy': '7,72'},
#  {'ticker': 'NVIF11B', 'dy': '3,52'},
#  {'ticker': 'OBAL11', 'dy': '-'},
#  {'ticker': 'OCRE11', 'dy': '2,65'},
#  {'ticker': 'OGHY11', 'dy': '13,02'},
#  {'ticker': 'OIAG11', 'dy': '17,13'},
#  {'ticker': 'ONEF11', 'dy': '21,76'},
#  {'ticker': 'OPTM11', 'dy': '-'},
#  {'ticker': 'ORPD11', 'dy': '-'},
#  {'ticker': 'OUCY11', 'dy': '-'},
#  {'ticker': 'OUFF11', 'dy': '11,78'},
#  {'ticker': 'OUJP11', 'dy': '14,08'},
#  {'ticker': 'OULG11', 'dy': '15,04'},
#  {'ticker': 'OURE11', 'dy': '14,43'},
#  {'ticker': 'PABY11', 'dy': '-'},
#  {'ticker': 'PATB11', 'dy': '-'},
#  {'ticker': 'PATC11', 'dy': '19,82'},
#  {'ticker': 'PATL11', 'dy': '10,47'},
#  {'ticker': 'PBLV11', 'dy': '8,50'},
#  {'ticker': 'PCAS11', 'dy': '-'},
#  {'ticker': 'PEMA11', 'dy': '18,43'},
#  {'ticker': 'PLCA11', 'dy': '15,71'},
#  {'ticker': 'PLCR11', 'dy': '13,02'},
#  {'ticker': 'PLOG11', 'dy': '13,27'},
#  {'ticker': 'PLRI11', 'dy': '6,72'},
#  {'ticker': 'PMFO11', 'dy': '-'},
#  {'ticker': 'PMIS11', 'dy': '-'},
#  {'ticker': 'PNCR11', 'dy': '5,37'},
#  {'ticker': 'PNDL11', 'dy': '0,96'},
#  {'ticker': 'PNLM11', 'dy': '-'},
#  {'ticker': 'PNLN11', 'dy': '-'},
#  {'ticker': 'PNPR11', 'dy': '-'},
#  {'ticker': 'PNRC11', 'dy': '11,17'},
#  {'ticker': 'PORD11', 'dy': '13,45'},
#  {'ticker': 'PQAG11', 'dy': '9,08'},
#  {'ticker': 'PQDP11', 'dy': '10,59'},
#  {'ticker': 'PRSN11B', 'dy': '11,60'},
#  {'ticker': 'PRSV11', 'dy': '-'},
#  {'ticker': 'PRTS11', 'dy': '0,05'},
#  {'ticker': 'PRZS11', 'dy': '-'},
#  {'ticker': 'PURB11', 'dy': '-'},
#  {'ticker': 'PVBI11', 'dy': '7,60'},
#  {'ticker': 'QAGR11', 'dy': '10,41'},
#  {'ticker': 'QAMI11', 'dy': '9,62'},
#  {'ticker': 'QIFF11', 'dy': '-'},
#  {'ticker': 'QIRI11', 'dy': '0,85'},
#  {'ticker': 'RBBV11', 'dy': '-'},
#  {'ticker': 'RBCB11', 'dy': '-'},
#  {'ticker': 'RBCO11', 'dy': '-'},
#  {'ticker': 'RBDS11', 'dy': '-'},
#  {'ticker': 'RBED11', 'dy': '11,13'},
#  {'ticker': 'RBFF11', 'dy': '9,98'},
#  {'ticker': 'RBGS11', 'dy': '0,62'},
#  {'ticker': 'RBHG11', 'dy': '13,67'},
#  {'ticker': 'RBHY11', 'dy': '15,05'},
#  {'ticker': 'RBIR11', 'dy': '4,40'},
#  {'ticker': 'RBIV11', 'dy': '-'},
#  {'ticker': 'RBLG11', 'dy': '10,62'},
#  {'ticker': 'RBOP11', 'dy': '18,95'},
#  {'ticker': 'RBRD11', 'dy': '10,65'},
#  {'ticker': 'RBRF11', 'dy': '8,94'},
#  {'ticker': 'RBRI11', 'dy': '3,56'},
#  {'ticker': 'RBRL11', 'dy': '9,01'},
#  {'ticker': 'RBRM11', 'dy': '8,06'},
#  {'ticker': 'RBRP11', 'dy': '5,57'},
#  {'ticker': 'RBRR11', 'dy': '10,94'},
#  {'ticker': 'RBRS11', 'dy': '7,75'},
#  {'ticker': 'RBRX11', 'dy': '14,26'},
#  {'ticker': 'RBRY11', 'dy': '14,01'},
#  {'ticker': 'RBTS11', 'dy': '35,95'},
#  {'ticker': 'RBVA11', 'dy': '10,45'},
#  {'ticker': 'RBVO11', 'dy': '2,78'},
#  {'ticker': 'RCFA11', 'dy': '-'},
#  {'ticker': 'RCFF11', 'dy': '1,24'},
#  {'ticker': 'RCKF11', 'dy': '-'},
#  {'ticker': 'RCRB11', 'dy': '5,79'},
#  {'ticker': 'RCRI11B', 'dy': '1,04'},
#  {'ticker': 'RDES11', 'dy': '-'},
#  {'ticker': 'RDPD11', 'dy': '21,58'},
#  {'ticker': 'RECR11', 'dy': '12,38'},
#  {'ticker': 'RECT11', 'dy': '11,64'},
#  {'ticker': 'RECX11', 'dy': '10,18'},
#  {'ticker': 'REIT11', 'dy': '4,49'},
#  {'ticker': 'RELG11', 'dy': '2,97'},
#  {'ticker': 'REON11', 'dy': '-'},
#  {'ticker': 'RFOF11', 'dy': '11,21'},
#  {'ticker': 'RINV11', 'dy': '13,18'},
#  {'ticker': 'RMAI11', 'dy': '4,70'},
#  {'ticker': 'RNDP11', 'dy': '11,64'},
#  {'ticker': 'RNGO11', 'dy': '10,42'},
#  {'ticker': 'ROOF11', 'dy': '6,69'},
#  {'ticker': 'RPRI11', 'dy': '12,47'},
#  {'ticker': 'RRCI11', 'dy': '13,94'},
#  {'ticker': 'RSPD11', 'dy': '8,33'},
#  {'ticker': 'RURA11', 'dy': '12,91'},
#  {'ticker': 'RVBI11', 'dy': '10,58'},
#  {'ticker': 'RZAG11', 'dy': '15,95'},
#  {'ticker': 'RZAK11', 'dy': '16,06'},
#  {'ticker': 'RZAT11', 'dy': '12,36'},
#  {'ticker': 'RZDM11', 'dy': '1,56'},
#  {'ticker': 'RZEO11', 'dy': '-'},
#  {'ticker': 'RZTR11', 'dy': '11,39'},
#  {'ticker': 'SAAG11', 'dy': '-'},
#  {'ticker': 'SACL11', 'dy': '-'},
#  {'ticker': 'SADI11', 'dy': '13,59'},
#  {'ticker': 'SAIC11B', 'dy': '-'},
#  {'ticker': 'SALI11', 'dy': '-'},
#  {'ticker': 'SAPI11', 'dy': '-'},
#  {'ticker': 'SARE11', 'dy': '13,55'},
#  {'ticker': 'SBCL11', 'dy': '-'},
#  {'ticker': 'SCPF11', 'dy': '5,41'},
#  {'ticker': 'SDIL11', 'dy': '10,00'},
#  {'ticker': 'SDIP11', 'dy': '-'},
#  {'ticker': 'SEED11', 'dy': '12,29'},
#  {'ticker': 'SEQR11', 'dy': '14,24'},
#  {'ticker': 'SFND11', 'dy': '0,12'},
#  {'ticker': 'SHDP11B', 'dy': '-'},
#  {'ticker': 'SHOP11', 'dy': '-'},
#  {'ticker': 'SHPH11', 'dy': '6,47'},
#  {'ticker': 'SHSO11', 'dy': '-'},
#  {'ticker': 'SIGR11', 'dy': '15,44'},
#  {'ticker': 'SJAU11', 'dy': '-'},
#  {'ticker': 'SLDZ11', 'dy': '-'},
#  {'ticker': 'SNAG11', 'dy': '13,58'},
#  {'ticker': 'SNCI11', 'dy': '12,31'},
#  {'ticker': 'SNEL11', 'dy': '2,42'},
#  {'ticker': 'SNFF11', 'dy': '9,74'},
#  {'ticker': 'SNLG11', 'dy': '4,16'},
#  {'ticker': 'SNME11', 'dy': '1,15'},
#  {'ticker': 'SOLR11', 'dy': '1,97'},
#  {'ticker': 'SPAF11', 'dy': '-'},
#  {'ticker': 'SPDE11', 'dy': '-'},
#  {'ticker': 'SPMO11', 'dy': '0,36'},
#  {'ticker': 'SPTW11', 'dy': '12,64'},
#  {'ticker': 'SPVJ11', 'dy': '-'},
#  {'ticker': 'SPXS11', 'dy': '13,35'},
#  {'ticker': 'SRVD11', 'dy': '3,08'},
#  {'ticker': 'STRX11', 'dy': '5,37'},
#  {'ticker': 'TBOF11', 'dy': '5,29'},
#  {'ticker': 'TCIN11', 'dy': '-'},
#  {'ticker': 'TCPF11', 'dy': '1.233,33'},
#  {'ticker': 'TELD11', 'dy': '-'},
#  {'ticker': 'TELF11', 'dy': '-'},
#  {'ticker': 'TELM11', 'dy': '-'},
#  {'ticker': 'TEPP11', 'dy': '7,84'},
#  {'ticker': 'TGAR11', 'dy': '13,67'},
#  {'ticker': 'THRA11', 'dy': '-'},
#  {'ticker': 'TJKB11', 'dy': '11,33'},
#  {'ticker': 'TMPS11', 'dy': '6,60'},
#  {'ticker': 'TORD11', 'dy': '2,24'},
#  {'ticker': 'TORM13', 'dy': '-'},
#  {'ticker': 'TOUR11', 'dy': '-'},
#  {'ticker': 'TRBL11', 'dy': '9,54'},
#  {'ticker': 'TRNT11', 'dy': '3,88'},
#  {'ticker': 'TRXB11', 'dy': '9,03'},
#  {'ticker': 'TRXF11', 'dy': '10,16'},
#  {'ticker': 'TSER11', 'dy': '11,36'},
#  {'ticker': 'TSNC11', 'dy': '-'},
#  {'ticker': 'TSNM11', 'dy': '-'},
#  {'ticker': 'TVRI11', 'dy': '10,81'},
#  {'ticker': 'UBSR11', 'dy': '-'},
#  {'ticker': 'UMED11', 'dy': '-'},
#  {'ticker': 'URPR11', 'dy': '16,38'},
#  {'ticker': 'VCJR11', 'dy': '11,80'},
#  {'ticker': 'VCRA11', 'dy': '15,47'},
#  {'ticker': 'VCRI11', 'dy': '13,61'},
#  {'ticker': 'VCRR11', 'dy': '12,29'},
#  {'ticker': 'VDSV11', 'dy': '-'},
#  {'ticker': 'VERE11', 'dy': '13,90'},
#  {'ticker': 'VGHF11', 'dy': '13,77'},
#  {'ticker': 'VGIA11', 'dy': '17,28'},
#  {'ticker': 'VGIP11', 'dy': '11,96'},
#  {'ticker': 'VGIR11', 'dy': '14,77'},
#  {'ticker': 'VIDS11', 'dy': '-'},
#  {'ticker': 'VIFI11', 'dy': '10,01'},
#  {'ticker': 'VILG11', 'dy': '8,32'},
#  {'ticker': 'VINO11', 'dy': '9,53'},
#  {'ticker': 'VISC11', 'dy': '8,79'},
#  {'ticker': 'VIUR11', 'dy': '10,94'},
#  {'ticker': 'VJFD11', 'dy': '-'},
#  {'ticker': 'VLIQ11', 'dy': '-'},
#  {'ticker': 'VLJS11', 'dy': '2,53'},
#  {'ticker': 'VLOL11', 'dy': '3,86'},
#  {'ticker': 'VOTS11', 'dy': '16,55'},
#  {'ticker': 'VPSI11', 'dy': '-'},
#  {'ticker': 'VRTA11', 'dy': '11,46'},
#  {'ticker': 'VSEC11', 'dy': '285,71'},
#  {'ticker': 'VSHO11', 'dy': '10,10'},
#  {'ticker': 'VSLH11', 'dy': '11,99'},
#  {'ticker': 'VTLT11', 'dy': '11,07'},
#  {'ticker': 'VTPA11', 'dy': '-'},
#  {'ticker': 'VTPL11', 'dy': '-'},
#  {'ticker': 'VTVI11', 'dy': '-'},
#  {'ticker': 'VTXI11', 'dy': '-'},
#  {'ticker': 'VVCO11', 'dy': '-'},
#  {'ticker': 'VVCR11', 'dy': '15,11'},
#  {'ticker': 'VVPR11', 'dy': '0,88'},
#  {'ticker': 'VVRI11', 'dy': '12,47'},
#  {'ticker': 'VXXV11', 'dy': '-'},
#  {'ticker': 'WHGR11', 'dy': '12,45'},
#  {'ticker': 'WPLZ11', 'dy': '7,98'},
#  {'ticker': 'WSEC11', 'dy': '17,57'},
#  {'ticker': 'WTSP11B', 'dy': '8,68'},
#  {'ticker': 'WVSC11', 'dy': '0,89'},
#  {'ticker': 'XBXO11', 'dy': '-'},
#  {'ticker': 'XPCA11', 'dy': '15,76'},
#  {'ticker': 'XPCI11', 'dy': '12,59'},
#  {'ticker': 'XPCM11', 'dy': '9,51'},
#  {'ticker': 'XPHT11', 'dy': '22,96'},
#  {'ticker': 'XPIN11', 'dy': '9,64'},
#  {'ticker': 'XPLG11', 'dy': '8,35'},
#  {'ticker': 'XPML11', 'dy': '8,62'},
#  {'ticker': 'XPPR11', 'dy': '6,35'},
#  {'ticker': 'XPSF11', 'dy': '10,82'},
#  {'ticker': 'XTED11', 'dy': '-'},
#  {'ticker': 'YCHY11', 'dy': '-'},
#  {'ticker': 'YUFI11', 'dy': '3,17'},
#  {'ticker': 'ZAVC11', 'dy': '-'},
#  {'ticker': 'ZAVI11', 'dy': '10,47'},
#  {'ticker': 'ZIFI11', 'dy': '0,33'}]

# %%
df = pd.DataFrame(fiis)

df.head()

df.shape
# Out:
# (553, 2)

# %%
df.to_csv('dados/lista-de-fiis.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.to_csv('dados2/lista-de-fiis.csv',index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'dados2'
